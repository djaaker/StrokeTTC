# %% [markdown]
# ## Try 1, this kinda went nowhere, but it's still here for documentation purposes

# %% [markdown]
# To help you prepare your EEG data for input into a ResNet model, we can go through the steps of loading the .edf files, preprocessing the data, and setting up the format for input into ResNet. Here's an outline of the process:
#
# 1. **Load .edf files**: We'll use the `pyEDFlib` library to load the EEG data.
# 2. **Preprocess the EEG data**: This may involve normalization or other preprocessing specific to EEG signals.
# 3. **Label encoding**: We'll ensure that the labels (normal or abnormal) are mapped into numerical values.
# 4. **Reshape data for ResNet**: ResNet typically expects input in a specific shape (e.g., (batch_size, height, width, channels)), so we'll format the EEG data accordingly.

# %%
import pyedflib
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# Paths to your 10 .edf files
file_paths = ['file1.edf', 'file2.edf', 'file3.edf', 'file4.edf', 'file5.edf',
              'file6.edf', 'file7.edf', 'file8.edf', 'file9.edf', 'file10.edf']

# Labels for the files: 'normal' or 'abnormal'
labels = ['normal', 'abnormal', 'normal', 'normal', 'abnormal', 
          'abnormal', 'normal', 'abnormal', 'normal', 'abnormal']

# Prepare label encoding
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)
categorical_labels = to_categorical(encoded_labels)

# Function to load and preprocess each .edf file
def load_and_preprocess_edf(file_path):
    f = pyedflib.EdfReader(file_path)
    num_signals = f.signals_in_file
    signal_data = np.zeros((num_signals, f.getNSamples()[0]))

    for i in range(num_signals):
        signal_data[i, :] = f.readSignal(i)
    
    f.close()

    # Preprocess data (e.g., normalization)
    # Here we simply normalize to 0-1 range as an example
    signal_data = (signal_data - np.min(signal_data)) / (np.max(signal_data) - np.min(signal_data))
    
    return signal_data

# Load and preprocess all the files
eeg_data = []
for path in file_paths:
    eeg_data.append(load_and_preprocess_edf(path))

# Convert the list to a numpy array
eeg_data = np.array(eeg_data)

# Reshape data to fit ResNet input shape (assuming 1D signals, we can reshape to (samples, height, width, channels))
# ResNet often takes 2D images, so you might need to adapt depending on your input size
eeg_data = np.expand_dims(eeg_data, axis=-1)  # Add channel dimension

print("EEG data shape:", eeg_data.shape)
print("Labels shape:", categorical_labels.shape)

# %% [markdown]
# ### Key Steps:
# 1. **Loading .edf files**: We use `pyedflib` to load the EEG signals.
# 2. **Preprocessing**: The data is normalized, but you can modify the preprocessing step based on your needs.
# 3. **Label Encoding**: The labels (normal or abnormal) are encoded into categorical values for training.
# 4. **ResNet Input Shape**: We ensure the EEG data is reshaped to the required input dimensions for ResNet (e.g., adding a channel dimension).
#
# Once the data is preprocessed, you can split it into training and test sets and feed it into the ResNet model.
#
# Let me know if you'd like to adjust anything, like the preprocessing or data augmentation!

# %% [markdown]
# ## Try 2 with pickle formatting

# %%
import os
import numpy as np
import pickle as pkl
import torch
from torch.utils.data import DataLoader, Dataset

# Define a custom dataset class to handle loading and processing of .edf files
class EEGDataset(Dataset):
    def __init__(self, data_folder, label):
        self.data_folder = data_folder
        self.label = label
        self.file_list = [f for f in os.listdir(data_folder) if f.endswith('.edf')]

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        file_path = os.path.join(self.data_folder, self.file_list[idx])
        try:
            # Load EEG data from .edf file using pickle (or any other preferred method)
            with open(file_path, 'rb') as f:
                data_pkl = pkl.load(f)
                signals = data_pkl['RAW_DATA'][0]  # Extract EEG signals from the pickled data
            return signals, self.label
        except (pkl.UnpicklingError, KeyError) as e:
            print(f"Error loading {file_path}: {e}")
            return None, None

# Prepare data loader function
def prepare_dataloaders(normal_folder, abnormal_folder, batch_size=16):
    normal_data = EEGDataset(normal_folder, label=0)
    abnormal_data = EEGDataset(abnormal_folder, label=1)

    # Combine datasets
    dataset = torch.utils.data.ConcatDataset([normal_data, abnormal_data])

    # Create DataLoader for batching
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

    return data_loader

# Custom collate function to handle None values
def collate_fn(batch):
    batch = [item for item in batch if item[0] is not None]
    if len(batch) == 0:
        return torch.Tensor(), torch.Tensor()
    data, labels = zip(*batch)
    return torch.stack([torch.Tensor(d) for d in data]), torch.Tensor(labels)

# Define paths to normal and abnormal folders
normal_folder = '/Users/User/Downloads/TUH EEG Corpus random files/normal'
abnormal_folder = '/Users/User/Downloads/TUH EEG Corpus random files/abnormal'

# Prepare the data loaders
data_loader = prepare_dataloaders(normal_folder, abnormal_folder)

# Iterate through the data loader
for batch_idx, (data, labels) in enumerate(data_loader):
    if data.size(0) == 0:
        print(f"Batch {batch_idx + 1} is empty due to loading errors.")
        continue
    print(f"Batch {batch_idx + 1} - Data Shape: {data.shape}, Labels: {labels}")
# Out:
# Error loading /Users/User/Downloads/TUH EEG Corpus random files/abnormal/aaaaaaaq_s004_t000.edf: unpickling stack underflow
# Error loading /Users/User/Downloads/TUH EEG Corpus random files/normal/aaaaaabn_s005_t000.edf: unpickling stack underflow
# Error loading /Users/User/Downloads/TUH EEG Corpus random files/abnormal/aaaaaacq_s008_t001.edf: unpickling stack underflow
# Error loading /Users/User/Downloads/TUH EEG Corpus random files/abnormal/aaaaaacq_s009_t000.edf: unpickling stack underflow
# Error loading /Users/User/Downloads/TUH EEG Corpus random files/normal/aaaaaaat_s002_t001.edf: unpickling stack underflow
# Error loading /Users/User/Downloads/TUH EEG Corpus random files/abnormal/aaaaaaav_s004_t000.edf: unpickling stack underflow
# Error loading /Users/User/Downloads/TUH EEG Corpus random files/normal/aaaaaaff_s002_t000.edf: unpickling stack underflow
# Error loading /Users/User/Downloads/TUH EEG Corpus random files/abnormal/aaaaaaaq_s005_t001.edf: unpickling stack underflow
# Error loading /Users/User/Downloads/TUH EEG Corpus random files/normal/aaaaaalk_s002_t000.edf: unpickling stack underflow
# Error loading /Users/User/Downloads/TUH EEG Corpus random files/normal/aaaaaama_s002_t000.edf: unpickling stack underflow
# Batch 1 is empty due to loading errors.

# %% [markdown]
# ## Try 3 using pyedflib (this one worked!)

# %% [markdown]
# Important note here, this isn't going to run for you straight away because for the sake of time I pulled the 10 data files from my downloads folder because pulling it from box wasn't working for me
#
# So either change the path to wherever the folder is for you (because it is in our shared box folder, and it's called TUH EEG Corpus random files), or figure out how to properly call it from box for me, because eventually we need a way to call all the data from some shared location

# %%
import os
import numpy as np
import pyedflib
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torchvision import models

# Function to find the length of the shortest signal and the maximum number of channels
def find_min_length_and_max_channels(folder_paths):
    min_length = float('inf')
    max_channels = 0
    
    for folder in folder_paths:
        for file_name in os.listdir(folder):
            if file_name.endswith('.edf'):
                file_path = os.path.join(folder, file_name)
                with pyedflib.EdfReader(file_path) as f:
                    n_signals = f.signals_in_file
                    if n_signals > max_channels:
                        max_channels = n_signals  # Track maximum number of channels
                    for i in range(n_signals):
                        signal_length = len(f.readSignal(i))
                        if signal_length < min_length:
                            min_length = signal_length  # Update if a smaller signal length is found
    
    return min_length, max_channels

# Function to load signals from the .edf files and pad if necessary
def load_edf_signals(file_path, target_length, target_channels):
    with pyedflib.EdfReader(file_path) as f:
        n_signals = f.signals_in_file
        signal_data = []
        for i in range(n_signals):
            signal = f.readSignal(i)
            truncated_signal = signal[:target_length]  # Truncate signal to target length
            signal_data.append(truncated_signal)
        
        # Pad channels with zeros if fewer than the target number of channels
        while len(signal_data) < target_channels:
            signal_data.append(np.zeros(target_length))
        
        signal_data = np.array(signal_data)  # Convert list to numpy array for consistency
    return signal_data

# Prepare data and labels function
def prepare_data(normal_folder, abnormal_folder, target_length, target_channels):
    data = []
    labels = []
    
    # Load normal files
    for file_name in os.listdir(normal_folder):
        if file_name.endswith('.edf'):
            file_path = os.path.join(normal_folder, file_name)
            signal_data = load_edf_signals(file_path, target_length, target_channels)
            data.append(signal_data)
            labels.append(0)  # Label 0 for normal
    
    # Load abnormal files
    for file_name in os.listdir(abnormal_folder):
        if file_name.endswith('.edf'):
            file_path = os.path.join(abnormal_folder, file_name)
            signal_data = load_edf_signals(file_path, target_length, target_channels)
            data.append(signal_data)
            labels.append(1)  # Label 1 for abnormal
    
    return np.array(data), np.array(labels)

# Paths to the folders
normal_folder = '/Users/User/Downloads/BME Senior Design/BME 489/TUH EEG Corpus random files/normal'
abnormal_folder = '/Users/User/Downloads/BME Senior Design/BME 489/TUH EEG Corpus random files/abnormal'

# Find the minimum signal length and maximum number of channels across both folders
folders = [normal_folder, abnormal_folder]
min_signal_length, max_channels = find_min_length_and_max_channels(folders)
print(f"Minimum signal length found: {min_signal_length}")
print(f"Maximum number of channels found: {max_channels}")

# Load and prepare the dataset with the minimum signal length and maximum channels
data, labels = prepare_data(normal_folder, abnormal_folder, min_signal_length, max_channels)

# Reshape data for ResNet (ResNet generally expects input shape of (n_samples, height, width, channels))
# Let's assume the EEG data is multichannel, so reshape accordingly

# UPDATE THE LABELS WITH THE KNOWN LABELS 

# THIS IS WHERE WE CAN UPLOAD PROCESSED DATA
#data = # max's dataframe (convert to numpy array)
#data = np.expand_dims(data, axis=-1)  # Add an extra dimension for channels if needed

# Check the shapes of data and labels
print("Data shape:", data.shape)
print("Labels shape:", labels.shape)

# Prepare the data: Shape should be (batch_size, 1, num_channels, signal_length)
data = torch.tensor(data, dtype=torch.float32)  # Data is (batch_size, num_channels, signal_length, 1)
data = data.permute(0, 3, 1, 2)  # Reshape to (batch_size, 1, num_channels, signal_length)

labels = torch.tensor(labels, dtype=torch.long)  # Labels as long tensor

# Create a dataset and dataloader
dataset = TensorDataset(data, labels)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)
# Out:
#   Cell In[8], line 89
#     data = # max's dataframe (convert to numpy array)
#            ^
# SyntaxError: invalid syntax

# %%
# Iterate through DataLoader and print each batch
for batch_idx, (data_batch, labels_batch) in enumerate(dataloader):
    print(f"Batch {batch_idx + 1}:")
    print("Data:", data_batch)
    print("Labels:", labels_batch)
    print()
# Out:
# Batch 1:
# Data: tensor([[[[ -6.2526, -11.7458,  -9.4569,  ...,  16.9407,  15.8726,  18.7718],
#           [-23.1898, -19.2226, -13.2716,  ...,  12.6683,   9.6165,  16.7882],
#           [ 12.0579,   9.1588,   9.4639,  ...,   5.0389,   2.2923,   5.0389],
#           ...,
#           [  0.0000,   0.0000,   0.0000,  ..., 266.9000, 266.9000, 266.9000],
#           [  0.0000,   0.0000,  20.0000,  ...,   0.3000,   0.3000,   0.3000],
#           [  0.0000,   0.0000,  33.2000,  ...,  96.6000,  96.6000,  96.6000]]],
#
#
#         [[[  0.3087,   2.7501,   8.7010,  ..., -44.2470, -47.2987, -54.6229],
#           [  3.5130,   4.2760,   9.6165,  ..., -48.8246, -50.6556, -58.7428],
#           [-21.0536, -18.4596, -17.2389,  ..., -12.2035, -13.5768, -20.4433],
#           ...,
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000],
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000],
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000]]]])
# Labels: tensor([0, 1])
#
# Batch 2:
# Data: tensor([[[[ 4.9077e+03,  4.9193e+03,  4.9060e+03,  ..., -1.4648e+02,
#            -1.4694e+02, -1.4709e+02],
#           [ 4.7229e+03,  4.7151e+03,  4.7433e+03,  ..., -2.0614e+02,
#            -2.0630e+02, -2.0675e+02],
#           [ 4.9081e+03,  4.9184e+03,  4.9068e+03,  ..., -1.1169e+02,
#            -1.1123e+02, -1.1139e+02],
#           ...,
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#             0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#             0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#             0.0000e+00,  0.0000e+00]]],
#
#
#         [[[-4.9130e+01, -4.6994e+01, -4.6841e+01,  ..., -6.4846e+01,
#            -6.6677e+01, -6.8051e+01],
#           [-4.7451e+01, -4.3179e+01, -4.3179e+01,  ..., -5.7522e+01,
#            -5.7217e+01, -5.7217e+01],
#           [-4.2111e+01, -4.1958e+01, -4.2111e+01,  ..., -5.0350e+01,
#            -5.4623e+01, -6.1947e+01],
#           ...,
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  7.7900e+01,
#             7.7900e+01,  7.7900e+01],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  8.0000e-01,
#             8.0000e-01,  8.0000e-01],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  5.9900e+01,
#             5.9900e+01,  5.9900e+01]]]])
# Labels: tensor([1, 0])
#
# Batch 3:
# Data: tensor([[[[ 48.6790,  44.1014,  42.4229,  ...,  12.0579,   5.9544,   6.1070],
#           [ 47.4583,  43.3384,  41.0496,  ...,   9.6165,   5.9544,   7.0225],
#           [-26.6994, -22.7321, -25.1735,  ...,  13.4312,  25.1805,  20.6028],
#           ...,
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000],
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000],
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000]]],
#
#
#         [[[  7.3277,  14.9571,  21.3658,  ..., -29.2934, -45.0099, -27.4623],
#           [  1.3768, -26.6994,  28.6900,  ..., -13.2716, -45.6202, -23.8002],
#           [  7.4803,  21.0606,  16.7882,  ...,   7.7855,  -4.1164,  -1.8276],
#           ...,
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000],
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000],
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000]]]])
# Labels: tensor([0, 1])
#
# Batch 4:
# Data: tensor([[[[ 45.4747,  47.4583,  47.3057,  ...,  40.5918,  40.1341,  38.9134],
#           [ 36.4720,  45.0169,  39.3711,  ...,  43.4910,  49.4419,  46.6954],
#           [ 50.5101,  51.5782,  52.3411,  ...,  16.3304,  16.1778,  12.6683],
#           ...,
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000],
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000],
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000]]],
#
#
#         [[[ -4.7267,  -8.0837,  -9.1518,  ..., -22.8847, -20.9010, -17.5441],
#           [  6.8699,   2.1397,   4.4285,  ..., -28.5304, -26.6994, -22.7321],
#           [-13.5768, -10.2199, -15.1027,  ...,  -0.7594, -35.0917, -10.6776],
#           ...,
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000],
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000],
#           [  0.0000,   0.0000,   0.0000,  ...,   0.0000,   0.0000,   0.0000]]]])
# Labels: tensor([1, 1])
#
# Batch 5:
# Data: tensor([[[[ 3.0071e+03,  2.9935e+03,  2.8914e+03,  ...,  2.3960e+01,
#             3.5099e+01,  3.1437e+01],
#           [ 2.9668e+03,  2.9552e+03,  2.8474e+03,  ...,  3.8303e+01,
#             4.9137e+01,  4.9900e+01],
#           [ 2.9822e+03,  2.9684e+03,  2.8685e+03,  ...,  2.0908e+01,
#             3.1742e+01,  2.9453e+01],
#           ...,
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#             0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#             0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#             0.0000e+00,  0.0000e+00]]],
#
#
#         [[[ 3.2078e+00,  8.7010e+00,  7.9381e+00,  ..., -4.0890e+01,
#            -3.1582e+01, -3.1582e+01],
#           [ 7.3277e+00,  1.7246e+01,  1.7551e+01,  ..., -1.4645e+01,
#            -1.7239e+01, -1.5408e+01],
#           [-1.5224e+00,  5.8018e+00,  2.5975e+00,  ..., -1.2509e+01,
#            -8.8466e+00, -5.7948e+00],
#           ...,
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#             0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#             0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#             0.0000e+00,  0.0000e+00]]]])
# Labels: tensor([0, 0])

# %%
# Use a prebuilt ResNet model and adjust the input for 2D data
class ResNet2D(nn.Module):
    def __init__(self):
        super(ResNet2D, self).__init__()
        # Load a pretrained ResNet (we'll modify it for EEG input)
        self.resnet = models.resnet18(pretrained=True)
        # Adjust the first convolutional layer to accept 1 input channel (from EEG)
        self.resnet.conv1 = nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
        # Change the final fully connected layer to match the number of classes (normal vs abnormal)
        num_ftrs = self.resnet.fc.in_features
        self.resnet.fc = nn.Linear(num_ftrs, 2)  # 2 classes (normal and abnormal)

    def forward(self, x):
        return self.resnet(x)

# Initialize the model
model = ResNet2D()
# Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    running_loss = 0.0  # Accumulate the loss for the epoch
    
    for i, (inputs, labels) in enumerate(dataloader):
        optimizer.zero_grad()  # Zero the parameter gradients
        
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()
        
        # Accumulate the loss for this batch
        running_loss += loss.item()
    
    # Calculate the average loss for the epoch
    avg_loss = running_loss / len(dataloader)
    
    # Print the average loss for the epoch
    print(f"[Epoch {epoch + 1}] Average Loss: {avg_loss:.3f}")

print("Finished Training")
# Out:
# /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [Epoch 1] Average Loss: 1.371
# [Epoch 2] Average Loss: 1.367
# [Epoch 3] Average Loss: 2.500
# [Epoch 4] Average Loss: 0.901
# [Epoch 5] Average Loss: 0.678
# [Epoch 6] Average Loss: 0.784
# [Epoch 7] Average Loss: 0.729
# [Epoch 8] Average Loss: 0.642
# [Epoch 9] Average Loss: 0.658
# [Epoch 10] Average Loss: 0.681
# Finished Training

# %%
#rsync -auxvL --delete nedc-tuh-eeg@www.isip.piconepress.com:data/tuh_eeg/TEST .
# Out:
#   Cell In[1], line 1
#     rsync -auxvL --delete nedc-tuh-eeg@www.isip.piconepress.com:data/tuh_eeg/TEST .
#                           ^
# SyntaxError: invalid syntax

# %%
# !pip install pipreqsnb
# Out:
# Collecting pipreqsnb
#   Downloading pipreqsnb-0.2.4.tar.gz (3.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pipreqs (from pipreqsnb)
#   Downloading pipreqs-0.5.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting docopt==0.6.2 (from pipreqs->pipreqsnb)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ipython==8.12.3 (from pipreqs->pipreqsnb)
#   Downloading ipython-8.12.3-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: nbconvert<8.0.0,>=7.11.0 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from pipreqs->pipreqsnb) (7.16.4)
# Collecting yarg==0.1.9 (from pipreqs->pipreqsnb)
#   Downloading yarg-0.1.9-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting backcall (from ipython==8.12.3->pipreqs->pipreqsnb)
#   Downloading backcall-0.2.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: decorator in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs->pipreqsnb) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs->pipreqsnb) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs->pipreqsnb) (0.1.7)
# Requirement already satisfied: pickleshare in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs->pipreqsnb) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs->pipreqsnb) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs->pipreqsnb) (2.18.0)
# Requirement already satisfied: stack-data in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs->pipreqsnb) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs->pipreqsnb) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs->pipreqsnb) (4.9.0)
# Requirement already satisfied: appnope in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from ipython==8.12.3->pipreqs->pipreqsnb) (0.1.4)
# Requirement already satisfied: requests in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from yarg==0.1.9->pipreqs->pipreqsnb) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (6.1.0)
# Requirement already satisfied: defusedxml in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (3.1.4)
# Requirement already satisfied: jupyter-core>=4.7 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (5.10.4)
# Requirement already satisfied: packaging in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (24.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (1.3.0)
# Requirement already satisfied: six>=1.9.0 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (1.16.0)
# Requirement already satisfied: webencodings in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from jedi>=0.16->ipython==8.12.3->pipreqs->pipreqsnb) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from jupyter-core>=4.7->nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (4.3.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (8.6.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (4.23.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from pexpect>4.3->ipython==8.12.3->pipreqs->pipreqsnb) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython==8.12.3->pipreqs->pipreqsnb) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from beautifulsoup4->nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from requests->yarg==0.1.9->pipreqs->pipreqsnb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from requests->yarg==0.1.9->pipreqs->pipreqsnb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from requests->yarg==0.1.9->pipreqs->pipreqsnb) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from requests->yarg==0.1.9->pipreqs->pipreqsnb) (2024.8.30)
# Requirement already satisfied: executing>=1.2.0 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from stack-data->ipython==8.12.3->pipreqs->pipreqsnb) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from stack-data->ipython==8.12.3->pipreqs->pipreqsnb) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from stack-data->ipython==8.12.3->pipreqs->pipreqsnb) (0.2.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (2.9.0)
# Requirement already satisfied: pyzmq>=23.0 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in /Users/User/anaconda3/envs/mne/lib/python3.12/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs->pipreqsnb) (6.4.1)
# Downloading pipreqs-0.5.0-py3-none-any.whl (33 kB)
# Downloading ipython-8.12.3-py3-none-any.whl (798 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.3/798.3 kB 5.4 MB/s eta 0:00:0000:01
# Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: pipreqsnb, docopt
#   Building wheel for pipreqsnb (setup.py) ... done
#   Created wheel for pipreqsnb: filename=pipreqsnb-0.2.4-py3-none-any.whl size=4129 sha256=7baecec545ea606e3f011d2318b779148bb76b9d2b47b7a4e6b714afc1faff81
#   Stored in directory: /Users/User/Library/Caches/pip/wheels/a6/f6/b8/5bd85cc669a8f4985ea596345127d33cf3569b037cf7e1194d
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=40761efe8d8dd8ad1a1bf6db1209a01b90f6f116836a2e83580fb02b2700c2f4
#   Stored in directory: /Users/User/Library/Caches/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built pipreqsnb docopt
# Installing collected packages: docopt, backcall, yarg, ipython, pipreqs, pipreqsnb
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.27.0
#     Uninstalling ipython-8.27.0:
#       Successfully uninstalled ipython-8.27.0
# Successfully installed backcall-0.2.0 docopt-0.6.2 ipython-8.12.3 pipreqs-0.5.0 pipreqsnb-0.2.4 yarg-0.1.9

# %%
# !pipreqsnb
# Out:
# pipreqs  /Users/User/Documents/GitHub/StrokeTTC
# INFO: Not scanning for jupyter notebooks.
# WARNING: Import named "__builtin__" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "__builtin__" does not exist or network problems
# WARNING: Import named "__pypy__" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "__pypy__" does not exist or network problems
# WARNING: Import named "_abcoll" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "_abcoll" does not exist or network problems
# WARNING: Import named "_cmsgpack" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "_cmsgpack" does not exist or network problems
# WARNING: Import named "_overlapped" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "_overlapped" does not exist or network problems
# WARNING: Import named "_scproxy" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "_scproxy" does not exist or network problems
# WARNING: Import named "_sha2" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "_sha2" does not exist or network problems
# WARNING: Import named "_tokenize" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "_tokenize" does not exist or network problems
# WARNING: Import named "_typeshed" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "_typeshed" does not exist or network problems
# WARNING: Import named "_typing" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "_typing" does not exist or network problems
# WARNING: Import named "_winapi" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "_winapi" does not exist or network problems
# WARNING: Import named "_winreg" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "_winreg" does not exist or network problems
# WARNING: Import named "_wmi" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "_wmi" does not exist or network problems
# WARNING: Import named "_xxinterpchannels" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "_xxinterpchannels" does not exist or network problems
# WARNING: Import named "attr" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "attr" was resolved to "attr:0.3.2" package (https://pypi.org/project/attr/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "colorama" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "colorama" was resolved to "colorama:0.4.6" package (https://pypi.org/project/colorama/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "ConfigParser" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "ConfigParser" was resolved to "configparser:7.1.0" package (https://pypi.org/project/configparser/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "cryptography" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "cryptography" was resolved to "cryptography:43.0.3" package (https://pypi.org/project/cryptography/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "ctags" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "ctags" does not exist or network problems
# WARNING: Import named "Cython" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "Cython" was resolved to "Cython:3.0.11" package (https://pypi.org/project/Cython/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "dl" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "dl" was resolved to "dl:0.1.0" package (https://pypi.org/project/dl/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "docutils" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "docutils" was resolved to "docutils:0.21.2" package (https://pypi.org/project/docutils/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "dummy_thread" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "dummy_thread" does not exist or network problems
# WARNING: Import named "filelock" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "filelock" was resolved to "filelock:3.16.1" package (https://pypi.org/project/filelock/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "htmlentitydefs" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "htmlentitydefs" does not exist or network problems
# WARNING: Import named "HTMLParser" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "HTMLParser" was resolved to "HTMLParser:0.0.2" package (https://pypi.org/project/HTMLParser/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "httplib" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "httplib" does not exist or network problems
# WARNING: Import named "hypothesis" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "hypothesis" was resolved to "hypothesis:6.118.8" package (https://pypi.org/project/hypothesis/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "ini2toml" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "ini2toml" was resolved to "ini2toml:0.15" package (https://pypi.org/project/ini2toml/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "java" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "java" does not exist or network problems
# WARNING: Import named "jnius" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "jnius" was resolved to "jnius:1.1.0" package (https://pypi.org/project/jnius/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "keyring" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "keyring" was resolved to "keyring:25.5.0" package (https://pypi.org/project/keyring/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "matplotlib" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "matplotlib" was resolved to "matplotlib:3.9.2" package (https://pypi.org/project/matplotlib/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "mne" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "mne" was resolved to "mne:1.8.0" package (https://pypi.org/project/mne/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "mod" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "mod" was resolved to "mod:0.3.0" package (https://pypi.org/project/mod/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "mod2" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "mod2" does not exist or network problems
# WARNING: Import named "nspkg" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "nspkg" does not exist or network problems
# WARNING: Import named "nt" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "nt" does not exist or network problems
# WARNING: Import named "ntlm" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "ntlm" does not exist or network problems
# WARNING: Import named "numpy" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "numpy" was resolved to "numpy:2.1.3" package (https://pypi.org/project/numpy/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "org" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "org" does not exist or network problems
# WARNING: Import named "pandas" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "pandas" was resolved to "pandas:2.2.3" package (https://pypi.org/project/pandas/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "path.py" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "path.py" was resolved to "path.py:12.5.0" package (https://pypi.org/project/path.py/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "Pillow" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "Pillow" was resolved to "pillow:11.0.0" package (https://pypi.org/project/pillow/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "pkg1" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "pkg1" was resolved to "pkg1:0.0.3" package (https://pypi.org/project/pkg1/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "protobuf" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "protobuf" was resolved to "protobuf:5.28.3" package (https://pypi.org/project/protobuf/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "pyOpenSSL" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "pyOpenSSL" was resolved to "pyOpenSSL:24.2.1" package (https://pypi.org/project/pyOpenSSL/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "pytest" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "pytest" was resolved to "pytest:8.3.3" package (https://pypi.org/project/pytest/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "pytorch_grad_cam" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "pytorch_grad_cam" does not exist or network problems
# WARNING: Import named "PyYAML" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "PyYAML" was resolved to "PyYAML:6.0.2" package (https://pypi.org/project/PyYAML/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "Queue" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "Queue" does not exist or network problems
# WARNING: Import named "redis" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "redis" was resolved to "redis:5.2.0" package (https://pypi.org/project/redis/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "scikit_learn" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "scikit_learn" was resolved to "scikit-learn:1.5.2" package (https://pypi.org/project/scikit-learn/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "scipy" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "scipy" was resolved to "scipy:1.14.1" package (https://pypi.org/project/scipy/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "sitecustomize" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "sitecustomize" does not exist or network problems
# WARNING: Import named "speechpy" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "speechpy" was resolved to "speechpy:2.4" package (https://pypi.org/project/speechpy/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "Sphinx" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "Sphinx" was resolved to "Sphinx:8.1.3" package (https://pypi.org/project/Sphinx/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "StringIO" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "StringIO" does not exist or network problems
# WARNING: Import named "tensorboardX" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "tensorboardX" was resolved to "tensorboardX:2.6.2.2" package (https://pypi.org/project/tensorboardX/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "tensorflow" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "tensorflow" was resolved to "tensorflow:2.18.0" package (https://pypi.org/project/tensorflow/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "tomli_w" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "tomli_w" was resolved to "tomli-w:1.1.0" package (https://pypi.org/project/tomli-w/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "torchaudio" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "torchaudio" was resolved to "torchaudio:2.5.1" package (https://pypi.org/project/torchaudio/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "torchinfo" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "torchinfo" was resolved to "torchinfo:1.8.0" package (https://pypi.org/project/torchinfo/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "torchsummary" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "torchsummary" was resolved to "torchsummary:1.5.1" package (https://pypi.org/project/torchsummary/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "trove_classifiers" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "trove_classifiers" was resolved to "trove-classifiers:2024.10.21.16" package (https://pypi.org/project/trove-classifiers/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "typeshed" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "typeshed" does not exist or network problems
# WARNING: Import named "urllib2" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "urllib2" does not exist or network problems
# WARNING: Import named "urllib3_secure_extra" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "urllib3_secure_extra" was resolved to "urllib3-secure-extra:0.1.0" package (https://pypi.org/project/urllib3-secure-extra/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "urlparse" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "urlparse" does not exist or network problems
# WARNING: Import named "usercustomize" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "usercustomize" was resolved to "usercustomize:1.0.0" package (https://pypi.org/project/usercustomize/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "vms_lib" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "vms_lib" does not exist or network problems
# WARNING: Import named "win32evtlog" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "win32evtlog" does not exist or network problems
# WARNING: Import named "win32evtlogutil" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Package "win32evtlogutil" does not exist or network problems
# WARNING: Import named "xmlrpclib" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "xmlrpclib" was resolved to "xmlrpclib:1.0.1" package (https://pypi.org/project/xmlrpclib/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "xx" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "xx" was resolved to "XX:3.3.2" package (https://pypi.org/project/XX/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# INFO: Successfully saved requirements file in /Users/User/Documents/GitHub/StrokeTTC/requirements.txt

# %%
import sys
# !{sys.executable} -m pip freeze > requirements.txt
