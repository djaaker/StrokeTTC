    'aaaaaqrs/', 'aaaaarsp/', 'aaaaasgd/', 'aaaaaskf/', 'aaaaatgc/'
]

seizureAll = seizureTrain + seizureEval + seizureDev

# %%
# display the number of elements in the seizureAll
print(len(seizureAll))

print(len(seizureTrain))
print(len(seizureEval))
print(len(seizureDev))
# Out:
# 672
# 576
# 43
# 53

# %%
epilepsyAll = [
    'aaaaaanr/', 'aaaaaawu/', 'aaaaabdn/', 'aaaaabhz/', 'aaaaabju/', 'aaaaacrz/', 
    'aaaaadkv/', 'aaaaaelp/', 'aaaaaeph/', 'aaaaaeqq/', 'aaaaaewf/', 'aaaaafif/', 
    'aaaaaflb/', 'aaaaagnh/', 'aaaaagxr/', 'aaaaaicb/', 'aaaaaiek/', 'aaaaaifn/', 
    'aaaaaifp/', 'aaaaaiiz/', 'aaaaaimz/', 'aaaaaint/', 'aaaaaiud/', 'aaaaajat/', 
    'aaaaajbn/', 'aaaaajqo/', 'aaaaajud/', 'aaaaajus/', 'aaaaakbt/', 'aaaaakfe/', 
    'aaaaakgl/', 'aaaaakgy/', 'aaaaaklt/', 'aaaaaklv/', 'aaaaakoq/', 'aaaaakqa/', 
    'aaaaakqq/', 'aaaaaktn/', 'aaaaakvr/', 'aaaaakyc/', 'aaaaalfg/', 'aaaaalgi/', 
    'aaaaalhr/', 'aaaaalib/', 'aaaaalim/', 'aaaaaliw/', 'aaaaalof/', 'aaaaalon/', 
    'aaaaalqm/', 'aaaaalug/', 'aaaaaluq/', 'aaaaalzg/', 'aaaaamde/', 'aaaaamgc/', 
    'aaaaamhb/', 'aaaaamic/', 'aaaaamkx/', 'aaaaamlf/', 'aaaaamlm/', 'aaaaamnj/', 
    'aaaaamoa/', 'aaaaamor/', 'aaaaamrq/', 'aaaaamsw/', 'aaaaamtl/', 'aaaaamuy/', 
    'aaaaamys/', 'aaaaanag/', 'aaaaandx/', 'aaaaanfk/', 'aaaaanfl/', 'aaaaanhr/', 
    'aaaaanjh/', 'aaaaankz/', 'aaaaanmf/', 'aaaaannz/', 'aaaaanog/', 'aaaaanwn/', 
    'aaaaanzp/', 'aaaaaock/', 'aaaaaocl/', 'aaaaaodl/', 'aaaaaogc/', 'aaaaaokm/', 
    'aaaaaoom/', 'aaaaaooo/', 'aaaaaoou/', 'aaaaaotl/', 'aaaaaoui/', 'aaaaaovm/', 
    'aaaaaowq/', 'aaaaaozy/', 'aaaaapfa/', 'aaaaapge/', 'aaaaaphz/', 'aaaaapjn/', 
    'aaaaapkm/', 'aaaaapri/', 'aaaaapvx/', 'aaaaapwd/'
]

# display the number of elements in the epilepsyAll
print(len(epilepsyAll))
# Out:
# 100

# %%
# upload the TUABEX_description_test_set.csv file
import pandas as pd
df = pd.read_csv(r"EEG_real_time_seizure_detection/TUHEEG_labels_Combined.csv")

# %%
print(df)
print(df['Label'].unique())
# Out:
#        Filename  Label
# 0      aaaaaaaa      2
# 1      aaaaaaab      3
# 2      aaaaaaab      2
# 3      aaaaaaab      2
# 4      aaaaaaac      2
# ...         ...    ...
# 24211  aaaaadez      3
# 24212  aaaaaccj      3
# 24213  aaaaammx      3
# 24214  aaaaadro      3
# 24215  aaaaafzg      3
#
# [24216 rows x 2 columns]
# [2 3 4 0 1]

# %%
abnBEX = df[df['pathological'] == 1].reset_index(drop=True)
normBEX = df[df['pathological'] == 0].reset_index(drop=True)
# abnBEX.head(40)

# %%
import pandas as pd
import re

# Assuming abnBEX is already defined
# Define the regex pattern
pattern = r'(?<=/edf/\d{3}/)([a-z]+?)/'

# Apply the regex to extract the names and store them in a list, ensuring that only string values are processed
abnAll = abnBEX['path_new'].apply(lambda x: re.search(pattern, x).group(1) if isinstance(x, str) and re.search(pattern, x) else None).dropna().tolist()
normAll = normBEX['path_new'].apply(lambda x: re.search(pattern, x).group(1) if isinstance(x, str) and re.search(pattern, x) else None).dropna().tolist()
print(len(abnAll))
# Out:
# 442

# %%
# Assuming abnAll, seizureAll, and epilepsyAll are already defined as lists of strings

# Assuming epilepsyAll and seizureAll are defined as lists of strings

# Remove all '/' characters from the strings in epilepsyAll and seizureAll
epilepsyAll = [entry.replace('/', '') for entry in epilepsyAll]
seizureAll = [entry.replace('/', '') for entry in seizureAll]

# Print to verify the result (optional)
print("epilepsyAll:", epilepsyAll)
print("seizureAll:", seizureAll)
print("normAll:", normAll)

# Convert lists to sets
set_abnAll = set(abnAll)
set_seizureAll = set(seizureAll)
set_epilepsyAll = set(epilepsyAll)
set_normAll = set(normAll)

print(len(set_abnAll))
print(len(set_seizureAll))
print(len(set_epilepsyAll))

# Find common elements between abnAll and seizureAll
common_abn_seizure = set_abnAll.intersection(set_seizureAll)

# Find common elements between abnAll and epilepsyAll
common_abn_epilepsy = set_abnAll.intersection(set_epilepsyAll)

# Print the number of common elements
print("Number of elements in abnAll also in seizureAll:", len(common_abn_seizure))
print("Number of elements in abnAll also in epilepsyAll:", len(common_abn_epilepsy))

# Assuming `common_all_three` contains the common elements in all three lists

# Calculate the number of elements not in common by subtracting the length of common elements from the total number of unique elements in all three lists
all_elements = set(abnAll) | set(seizureAll) | set(epilepsyAll) | set(normAll) # Union of all elements
print(all_elements)
# Out:
# epilepsyAll: ['aaaaaanr', 'aaaaaawu', 'aaaaabdn', 'aaaaabhz', 'aaaaabju', 'aaaaacrz', 'aaaaadkv', 'aaaaaelp', 'aaaaaeph', 'aaaaaeqq', 'aaaaaewf', 'aaaaafif', 'aaaaaflb', 'aaaaagnh', 'aaaaagxr', 'aaaaaicb', 'aaaaaiek', 'aaaaaifn', 'aaaaaifp', 'aaaaaiiz', 'aaaaaimz', 'aaaaaint', 'aaaaaiud', 'aaaaajat', 'aaaaajbn', 'aaaaajqo', 'aaaaajud', 'aaaaajus', 'aaaaakbt', 'aaaaakfe', 'aaaaakgl', 'aaaaakgy', 'aaaaaklt', 'aaaaaklv', 'aaaaakoq', 'aaaaakqa', 'aaaaakqq', 'aaaaaktn', 'aaaaakvr', 'aaaaakyc', 'aaaaalfg', 'aaaaalgi', 'aaaaalhr', 'aaaaalib', 'aaaaalim', 'aaaaaliw', 'aaaaalof', 'aaaaalon', 'aaaaalqm', 'aaaaalug', 'aaaaaluq', 'aaaaalzg', 'aaaaamde', 'aaaaamgc', 'aaaaamhb', 'aaaaamic', 'aaaaamkx', 'aaaaamlf', 'aaaaamlm', 'aaaaamnj', 'aaaaamoa', 'aaaaamor', 'aaaaamrq', 'aaaaamsw', 'aaaaamtl', 'aaaaamuy', 'aaaaamys', 'aaaaanag', 'aaaaandx', 'aaaaanfk', 'aaaaanfl', 'aaaaanhr', 'aaaaanjh', 'aaaaankz', 'aaaaanmf', 'aaaaannz', 'aaaaanog', 'aaaaanwn', 'aaaaanzp', 'aaaaaock', 'aaaaaocl', 'aaaaaodl', 
# ...

# %%
def extract_lines_start_a_end_underscore(file_path):
    results = []
    
    with open(file_path, 'r') as file:
        for line in file:
            line = line.strip()
            if line.startswith('a') and line.endswith('_'):
                results.append(line)
    
    return results

# File path provided by user
file_path = r"C:\Users\dalto\Box Sync\New Text Document.txt"
# Calling the function and storing the result
results = extract_lines_start_a_end_underscore(file_path)

# Print the results
for result in results:
    print(result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 15
#      13 file_path = r"C:\Users\dalto\Box Sync\New Text Document.txt"
#      14 # Calling the function and storing the result
# ---> 15 results = extract_lines_start_a_end_underscore(file_path)
#      17 # Print the results
#      18 for result in results:
#
# Cell In[12], line 4, in extract_lines_start_a_end_underscore(file_path)
#       1 def extract_lines_start_a_end_underscore(file_path):
#       2     results = []
# ----> 4     with open(file_path, 'r') as file:
#       5         for line in file:
#       6             line = line.strip()
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
# ...

# %%
# create a dataframe that contains the name of each subject and a 0,1,2,3 depending on if the subject is normal, seizure, epilepsy, or abnormal
df = pd.DataFrame(all_elements, columns=['name'])
df['label'] = 0
seizureNames = [name for name in df['name'] if seizureAll.__contains__(name)]
epilepsyNames = [name for name in df['name'] if epilepsyAll.__contains__(name)]
abnNames = [name for name in df['name'] if abnAll.__contains__(name)]
df.loc[df['name'].isin(seizureNames), 'label'] = 1
df.loc[df['name'].isin(epilepsyNames), 'label'] = 2
df.loc[df['name'].isin(abnNames), 'label'] = 3

# sort the dataframe by the label
df = df.sort_values(by='label').reset_index(drop=True)

df.head(40)
# Out:
#          name  label
# 0    aaaaavjq      0
# 1    aaaaaaog      0
# 2    aaaaajpb      0
# 3    aaaaasbl      0
# 4    aaaaavfn      0
# ..        ...    ...
# 395  aaaaasfw      1
# 396  aaaaaqyo      1
# 397  aaaaanbv      1
# 398  aaaaabxr      1
# 399  aaaaagdr      1
#
# [400 rows x 2 columns]
